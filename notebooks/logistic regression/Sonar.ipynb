# %%
import sys
sys.path.insert(0, "../..")

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from logistic_regression import LogisticRegressionGD
from extrapolation import *
from experiments import Experiment

# %%
data = pd.read_csv("../../../sonar.csv", header=None)
data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
X = data.loc[:, data.columns[:-1]].values
X = np.concatenate([np.ones((X.shape[0], 1)), X], axis=1)
y = data.loc[:, data.columns[-1]]
y = np.where(y == "R", 1, -1)

X = torch.tensor(X)
y = torch.tensor(y)

X.shape, y.shape
# Out:
# (torch.Size([208, 61]), torch.Size([208]))

# %%
np.random.seed(2020)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
model = LogisticRegressionGD(X_train, y_train, 1e-2)

# %%
model.fit(1e-4, max_iter=1000000)

# %%
preds = model.predict(X_test)
torch.mean((preds == y_test).double())
# Out:
# tensor(0.8095, dtype=torch.float64)

# %%
len(model.log)
# Out:
# 24701

# %%
k = 2
experiment = Experiment(model.log, model.obj, values=model.value_log)

# %%
experiment.run_method("MPE", MPE, k, method_kwargs={"qr": False})

# %%
experiment.run_method("MPE+QR", MPE, k, method_kwargs={"qr": True})

# %%
experiment.run_method("RRE", RRE, k, method_kwargs={"qr": False})

# %%
experiment.run_method("RRE+QR", RRE, k, method_kwargs={"qr": True})

# %%
experiment.run_method("Regularized RRE", regularized_RRE, k, method_kwargs={"lambda_": 1e-15})

# %%
plt.figure(figsize=(14, 8))
experiment.plot_values(n=10000)
plt.ylim((50, 80))
plt.legend()

# %%
plt.figure(figsize=(14, 8))
experiment.plot_log_diff(n=10000)
plt.legend()

# %%
df = experiment.value_df()
df.to_csv(f"results/sonar2:k={k}.csv")

# %%
k = 6
experiment = Experiment(model.log, model.obj, values=model.value_log)

# %%
# %%time
experiment.run_method("MPE", MPE, k, method_kwargs={"qr": False})
# Out:
# CPU times: user 17.1 s, sys: 7.68 s, total: 24.8 s
# Wall time: 6.57 s

# %%
# %%time
experiment.run_method("RRE", RRE, k, method_kwargs={"qr": False})
# Out:
# CPU times: user 14 s, sys: 6.47 s, total: 20.5 s
# Wall time: 5.43 s

# %%
# %%time
experiment.run_method("MPE+QR", MPE, k, method_kwargs={"qr": True})
# Out:
# CPU times: user 21.2 s, sys: 9.57 s, total: 30.8 s
# Wall time: 8.11 s

# %%
# %%time
experiment.run_method("RRE+QR", RRE, k, method_kwargs={"qr": True})
# Out:
# CPU times: user 17.8 s, sys: 8.01 s, total: 25.8 s
# Wall time: 6.87 s

# %%
# %%time
experiment.run_method("Regularized RRE", regularized_RRE, k, method_kwargs={"lambda_": 1e-10})
# Out:
# CPU times: user 21.6 s, sys: 9.07 s, total: 30.7 s
# Wall time: 8.08 s

# %%
# %%time
experiment.run_method("RNA", RNA, k, method_kwargs={"lambda_range": (1e-15, 1e-3), "linesearch": False, "norm": False})
# Out:
# CPU times: user 1min 33s, sys: 43 s, total: 2min 16s
# Wall time: 37.2 s

# %%
# %%time
experiment.run_method("RNA+norm", RNA, k, method_kwargs={"lambda_range": (1e-15, 1e-3), "linesearch": False})
# Out:
# CPU times: user 2min, sys: 59.1 s, total: 2min 59s
# Wall time: 56 s

# %%
# %%time
experiment.run_method("RNA+ls", RNA, k, method_kwargs={"lambda_range": (1e-15, 1e-3), "linesearch": True})
# Out:
# CPU times: user 2min 17s, sys: 1min 8s, total: 3min 25s
# Wall time: 1min 4s

# %%
# %%time
experiment.run_method("RNA+Cholesky", RNA_cholesky, k, method_kwargs={"lambda_range": (1e-15, 1e-3), "linesearch": False, "norm": False})
# Out:
# CPU times: user 7min 29s, sys: 3min 28s, total: 10min 57s
# Wall time: 3min 11s

# %%
# %%time
experiment.run_method("RNA+Cholesky+norm", RNA_cholesky, k, method_kwargs={"lambda_range": (1e-15, 1e-3), "linesearch": False, "norm": True})
# Out:
# CPU times: user 8min 26s, sys: 4min, total: 12min 27s
# Wall time: 3min 54s

# %%
plt.figure(figsize=(14, 8))
experiment.plot_values(n=10000)
plt.ylim(50, 80)
plt.legend()

# %%
plt.figure(figsize=(14, 8))
experiment.plot_log_diff(n=10000)
plt.legend()

# %%
stable_methods = ["MPE+QR", "RRE+QR", "Regularized RRE", "RNA", "RNA+norm", "RNA+ls", "RNA+Cholesky", "RNA+Cholesky+norm"]
plt.figure(figsize=(14, 8))
experiment.plot_values(n=10000, methods=stable_methods)
plt.ylim(50, 70)
plt.legend()

# %%
plt.figure(figsize=(14, 8))
experiment.plot_log_diff(n=10000, methods=stable_methods)
plt.ylim(None, 2)
plt.legend()

# %%
model.theta = experiment.best_x
preds = model.predict(X_test)
torch.mean((preds == y_test).double())
# Out:
# tensor(0.8095, dtype=torch.float64)

# %%
df = experiment.value_df()
df.to_csv(f"results/sonar2:k={k}.csv")
