# %%
import torch
from torch import nn
from torchvision import models
from copy import deepcopy
import os

from nn_extrapolation import AcceleratedSGD
from nn_utils import *

# %%
trainer = Trainer(
    device="cuda:0",
    loss_fn=nn.NLLLoss(reduction="mean"),
    val_loss_fn=nn.NLLLoss(reduction="sum"),
)

# %%
dl = load_dataset(
    dataset="CIFAR10",
    root=os.path.join("/tmp", os.environ["USER"], "CIFAR"),
    augmentation=transforms.RandomAffine(10, scale=(0.9, 1.1), translate=(0.2, 0.2)),
    validation_split=0.2,
    batch_size=128,
    num_workers=10,
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def make_model():
    model = models.resnet18(pretrained=False)
    model.fc = nn.Sequential(
        nn.Linear(512, 10),
        nn.LogSoftmax(-1)
    )
    return model

# %% [markdown]
# ## Momentum

# %%
model = make_model()
model.to(trainer.device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )

# %%
trainer.validation(model, dl["valid"])
# Out:
# (0.1028, 2.3495226707458494)

# %%
optimizer = AcceleratedSGD(model.parameters(), 1e-1, k=10, momentum=0.9, weight_decay=1e-5, lambda_=1e-8)
logger = Logger("resnet_log_augmentation-early_stopping.txt.no_resizing")

# %%
max_epochs = 300
early_stopping = EarlyStopping(15)

for epoch in range(max_epochs):
    train_loss = trainer.train_epoch(model, optimizer, dl["train"])
    optimizer.finish_epoch()
    val_acc, val_loss = trainer.validation(model, dl["valid"])
    logger.log("Epoch", epoch+1, "|", 
          f"Training loss: {train_loss:.4f}, validation accuracy: {val_acc:.4f}, validation loss: {val_loss:.4f}")
    if early_stopping.should_stop(val_loss):
        break
# Out:
# 100%|██████████| 313/313 [00:17<00:00, 18.14it/s, loss=2.3503]
# Epoch 1 | Training loss: 2.3503, validation accuracy: 0.3431, validation loss: 1.7452
# 100%|██████████| 313/313 [00:17<00:00, 17.41it/s, loss=1.7535]
# Epoch 2 | Training loss: 1.7535, validation accuracy: 0.3928, validation loss: 1.6418
# 100%|██████████| 313/313 [00:18<00:00, 16.99it/s, loss=1.5942]
# Epoch 3 | Training loss: 1.5942, validation accuracy: 0.4352, validation loss: 1.5090
# 100%|██████████| 313/313 [00:18<00:00, 17.02it/s, loss=1.4778]
# Epoch 4 | Training loss: 1.4778, validation accuracy: 0.4979, validation loss: 1.3699
# 100%|██████████| 313/313 [00:18<00:00, 17.17it/s, loss=1.3883]
# Epoch 5 | Training loss: 1.3883, validation accuracy: 0.5433, validation loss: 1.2724
# 100%|██████████| 313/313 [00:18<00:00, 17.32it/s, loss=1.3118]
# Epoch 6 | Training loss: 1.3118, validation accuracy: 0.5667, validation loss: 1.1915
# 100%|██████████| 313/313 [00:18<00:00, 17.02it/s, loss=1.2398]
# Epoch 7 | Training loss: 1.2398, validation accuracy: 0.5948, validation loss: 1.1415
# 100%|██████████| 313/313 [00:18<00:00, 17.17it/s, loss=1.1886]
# Epoch 8 | Training loss: 1.1886, validation accuracy: 0.6059, validation loss: 1.0789
# 100%|██████████| 313/313 [00:18<00:00, 17.06it/s, loss=1.1389]
# Epoch 9 | Training loss: 1.1389, validation accuracy: 0.6292, validation loss: 1.0352
# 100%|██████████| 313/313 [00:18<00:00, 17.13it/s, loss=1.0971]
# Epoch 10 | Training loss: 1.0971, validation accuracy: 0.6415, validation loss: 1.0224
# 100%|██████████| 313/313 [00:18<00:00, 17.06it/s, loss=1.0402]
# Epoch 11 | Training loss: 1.0402, validation accuracy: 0.6557, validation loss: 0.9801
# 100%|██████████| 313/313 [00:18<00:00, 17.01it/s, loss=1.0070]
# Epoch 12 | Training loss: 1.0070, validation accuracy: 0.6671, validation loss: 1.1220
# 100%|██████████| 313/313 [00:18<00:00, 17.06it/s, loss=0.9566]
# Epoch 13 | Training loss: 0.9566, validation accuracy: 0.6929, validation loss: 0.8765
# 100%|██████████| 313/313 [00:18<00:00, 17.01it/s, loss=0.9365]
# Epoch 14 | Training loss: 0.9365, validation accuracy: 0.6992, validation loss: 0.8846
# 100%|██████████| 313/313 [00:18<00:00, 17.16it/s, loss=0.9017]
# Epoch 15 | Training loss: 0.9017, validation accuracy: 0.6995, validation loss: 0.8720
# 100%|██████████| 313/313 [00:18<00:00, 17.12it/s, loss=0.8658]
# Epoch 16 | Training loss: 0.8658, validation accuracy: 0.6855, validation loss: 0.9182
# 100%|██████████| 313/313 [00:18<00:00, 16.97it/s, loss=0.8429]
# Epoch 17 | Training loss: 0.8429, validation accuracy: 0.7336, validation loss: 0.7868
# 100%|██████████| 313/313 [00:18<00:00, 17.06it/s, loss=0.8189]
# Epoch 18 | Training loss: 0.8189, validation accuracy: 0.6994, validation loss: 0.8924
# 100%|██████████| 313/313 [00:18<00:00, 16.91it/s, loss=0.8027]
# Epoch 19 | Training loss: 0.8027, validation accuracy: 0.7184, validation loss: 0.8232
# 100%|██████████| 313/313 [00:18<00:00, 16.89it/s, loss=0.7767]
# Epoch 20 | Training loss: 0.7767, validation accuracy: 0.7384, validation loss: 0.7511
# 100%|██████████| 313/313 [00:18<00:00, 16.82it/s, loss=0.7564]
# Epoch 21 | Training loss: 0.7564, validation accuracy: 0.7160, validation loss: 0.8289
# 100%|██████████| 313/313 [00:18<00:00, 16.96it/s, loss=0.7422]
# Epoch 22 | Training loss: 0.7422, validation accuracy: 0.7411, validation loss: 0.7715
# 100%|██████████| 313/313 [00:18<00:00, 16.81it/s, loss=0.7209]
# Epoch 23 | Training loss: 0.7209, validation accuracy: 0.7355, validation loss: 0.8075
# 100%|██████████| 313/313 [00:18<00:00, 16.92it/s, loss=0.7023]
# Epoch 24 | Training loss: 0.7023, validation accuracy: 0.7416, validation loss: 0.7731
# 100%|██████████| 313/313 [00:18<00:00, 16.87it/s, loss=0.6860]
# Epoch 25 | Training loss: 0.6860, validation accuracy: 0.7491, validation loss: 0.7820
# 100%|██████████| 313/313 [00:18<00:00, 16.87it/s, loss=0.6666]
# Epoch 26 | Training loss: 0.6666, validation accuracy: 0.7653, validation loss: 0.7072
# 100%|██████████| 313/313 [00:18<00:00, 16.91it/s, loss=0.6559]
# Epoch 27 | Training loss: 0.6559, validation accuracy: 0.7560, validation loss: 0.7423
# 100%|██████████| 313/313 [00:18<00:00, 16.79it/s, loss=0.6465]
# Epoch 28 | Training loss: 0.6465, validation accuracy: 0.7597, validation loss: 0.7663
# 100%|██████████| 313/313 [00:18<00:00, 16.94it/s, loss=0.6450]
# Epoch 29 | Training loss: 0.6450, validation accuracy: 0.7741, validation loss: 0.6802
# 100%|██████████| 313/313 [00:18<00:00, 16.72it/s, loss=0.6216]
# Epoch 30 | Training loss: 0.6216, validation accuracy: 0.7659, validation loss: 0.6908
# 100%|██████████| 313/313 [00:18<00:00, 16.91it/s, loss=0.6126]
# Epoch 31 | Training loss: 0.6126, validation accuracy: 0.7682, validation loss: 0.7257
# 100%|██████████| 313/313 [00:18<00:00, 16.80it/s, loss=0.5962]
# Epoch 32 | Training loss: 0.5962, validation accuracy: 0.7750, validation loss: 0.7009
# 100%|██████████| 313/313 [00:18<00:00, 16.83it/s, loss=0.5841]
# Epoch 33 | Training loss: 0.5841, validation accuracy: 0.7799, validation loss: 0.6609
# 100%|██████████| 313/313 [00:18<00:00, 16.81it/s, loss=0.5726]
# Epoch 34 | Training loss: 0.5726, validation accuracy: 0.7737, validation loss: 0.6801
# 100%|██████████| 313/313 [00:18<00:00, 16.73it/s, loss=0.5662]
# Epoch 35 | Training loss: 0.5662, validation accuracy: 0.7648, validation loss: 0.7046
# 100%|██████████| 313/313 [00:18<00:00, 16.84it/s, loss=0.5530]
# Epoch 36 | Training loss: 0.5530, validation accuracy: 0.7765, validation loss: 0.6734
# 100%|██████████| 313/313 [00:18<00:00, 16.71it/s, loss=0.5494]
# Epoch 37 | Training loss: 0.5494, validation accuracy: 0.7914, validation loss: 0.6335
# 100%|██████████| 313/313 [00:18<00:00, 16.83it/s, loss=0.5469]
# Epoch 38 | Training loss: 0.5469, validation accuracy: 0.7818, validation loss: 0.6585
# 100%|██████████| 313/313 [00:18<00:00, 16.73it/s, loss=0.5282]
# Epoch 39 | Training loss: 0.5282, validation accuracy: 0.7892, validation loss: 0.6361
# 100%|██████████| 313/313 [00:18<00:00, 16.96it/s, loss=0.5181]
# Epoch 40 | Training loss: 0.5181, validation accuracy: 0.7750, validation loss: 0.7029
# 100%|██████████| 313/313 [00:18<00:00, 16.74it/s, loss=0.5134]
# Epoch 41 | Training loss: 0.5134, validation accuracy: 0.7792, validation loss: 0.6583
# 100%|██████████| 313/313 [00:18<00:00, 16.61it/s, loss=0.4990]
# Epoch 42 | Training loss: 0.4990, validation accuracy: 0.7834, validation loss: 0.6763
# 100%|██████████| 313/313 [00:18<00:00, 16.78it/s, loss=0.5006]
# Epoch 43 | Training loss: 0.5006, validation accuracy: 0.7775, validation loss: 0.6871
# 100%|██████████| 313/313 [00:18<00:00, 16.71it/s, loss=0.4904]
# Epoch 44 | Training loss: 0.4904, validation accuracy: 0.7840, validation loss: 0.6827
# 100%|██████████| 313/313 [00:18<00:00, 16.84it/s, loss=0.4789]
# Epoch 45 | Training loss: 0.4789, validation accuracy: 0.7818, validation loss: 0.6894
# 100%|██████████| 313/313 [00:18<00:00, 16.67it/s, loss=0.4794]
# Epoch 46 | Training loss: 0.4794, validation accuracy: 0.7899, validation loss: 0.6418
# 100%|██████████| 313/313 [00:18<00:00, 16.94it/s, loss=0.4647]
# Epoch 47 | Training loss: 0.4647, validation accuracy: 0.7989, validation loss: 0.6264
# 100%|██████████| 313/313 [00:18<00:00, 16.76it/s, loss=0.4544]
# Epoch 48 | Training loss: 0.4544, validation accuracy: 0.7909, validation loss: 0.6612
# 100%|██████████| 313/313 [00:18<00:00, 16.79it/s, loss=0.4499]
# Epoch 49 | Training loss: 0.4499, validation accuracy: 0.7896, validation loss: 0.6732
# 100%|██████████| 313/313 [00:18<00:00, 16.78it/s, loss=0.4463]
# Epoch 50 | Training loss: 0.4463, validation accuracy: 0.7880, validation loss: 0.6924
# 100%|██████████| 313/313 [00:18<00:00, 16.65it/s, loss=0.4390]
# Epoch 51 | Training loss: 0.4390, validation accuracy: 0.8019, validation loss: 0.6176
# 100%|██████████| 313/313 [00:18<00:00, 16.85it/s, loss=0.4320]
# Epoch 52 | Training loss: 0.4320, validation accuracy: 0.7761, validation loss: 0.7065
# 100%|██████████| 313/313 [00:18<00:00, 16.62it/s, loss=0.4335]
# Epoch 53 | Training loss: 0.4335, validation accuracy: 0.7985, validation loss: 0.6461
# 100%|██████████| 313/313 [00:18<00:00, 16.78it/s, loss=0.4191]
# Epoch 54 | Training loss: 0.4191, validation accuracy: 0.7956, validation loss: 0.6407
# 100%|██████████| 313/313 [00:18<00:00, 16.71it/s, loss=0.4106]
# Epoch 55 | Training loss: 0.4106, validation accuracy: 0.7917, validation loss: 0.6666
# 100%|██████████| 313/313 [00:18<00:00, 16.84it/s, loss=0.4107]
# Epoch 56 | Training loss: 0.4107, validation accuracy: 0.7955, validation loss: 0.6657
# 100%|██████████| 313/313 [00:18<00:00, 16.75it/s, loss=0.3964]
# Epoch 57 | Training loss: 0.3964, validation accuracy: 0.7954, validation loss: 0.6431
# 100%|██████████| 313/313 [00:18<00:00, 16.78it/s, loss=0.3981]
# Epoch 58 | Training loss: 0.3981, validation accuracy: 0.7935, validation loss: 0.6762
# 100%|██████████| 313/313 [00:18<00:00, 16.83it/s, loss=0.3897]
# Epoch 59 | Training loss: 0.3897, validation accuracy: 0.7992, validation loss: 0.6610
# 100%|██████████| 313/313 [00:18<00:00, 16.84it/s, loss=0.3844]
# Epoch 60 | Training loss: 0.3844, validation accuracy: 0.8003, validation loss: 0.6585
# 100%|██████████| 313/313 [00:18<00:00, 16.81it/s, loss=0.3761]
# Epoch 61 | Training loss: 0.3761, validation accuracy: 0.7879, validation loss: 0.7173
# 100%|██████████| 313/313 [00:18<00:00, 16.85it/s, loss=0.3709]
# Epoch 62 | Training loss: 0.3709, validation accuracy: 0.7961, validation loss: 0.6552
# 100%|██████████| 313/313 [00:18<00:00, 16.87it/s, loss=0.3684]
# Epoch 63 | Training loss: 0.3684, validation accuracy: 0.7944, validation loss: 0.7086
# 100%|██████████| 313/313 [00:18<00:00, 16.94it/s, loss=0.3628]
# Epoch 64 | Training loss: 0.3628, validation accuracy: 0.8015, validation loss: 0.6439
# 100%|██████████| 313/313 [00:18<00:00, 16.75it/s, loss=0.3578]
# Epoch 65 | Training loss: 0.3578, validation accuracy: 0.7923, validation loss: 0.7041
# 100%|██████████| 313/313 [00:18<00:00, 16.83it/s, loss=0.3590]
# Epoch 66 | Training loss: 0.3590, validation accuracy: 0.7996, validation loss: 0.6683

# %%
train_score = trainer.validation(model, dl["train"])
valid_score = trainer.validation(model, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
# Out:
# Train: (0.884175, 0.32832401685714724)
# Valid: (0.7996, 0.6683076038360596)

# %%
optimizer.param_groups[0]["method"] = "RNA"
logger.log(optimizer.param_groups[0]["method"])
model.cpu()
model_acc = deepcopy(model)
optimizer.accelerate()
optimizer.store_parameters([model_acc.parameters()])
# Out:
# RNA

# %%
model_acc.cuda()
train_score = trainer.validation(model_acc, dl["train"])
valid_score = trainer.validation(model_acc, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
model_acc.cpu()
model.cuda()
# Out:
# Train: (0.899325, 0.2843654980182648)
# Valid: (0.8166, 0.5918278775215149)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )

# %%
optimizer.param_groups[0]["method"] = "RRE"
logger.log(optimizer.param_groups[0]["method"])
model.cpu()
model_acc = deepcopy(model)
optimizer.accelerate()
optimizer.store_parameters([model_acc.parameters()])
# Out:
# RRE

# %%
model_acc.cuda()
train_score = trainer.validation(model_acc, dl["train"])
valid_score = trainer.validation(model_acc, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
model_acc.cpu()
model.cuda()
# Out:
# Train: (0.901175, 0.28274290132522584)
# Valid: (0.8166, 0.5918271024703979)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )

# %%
optimizer.param_groups[0]["method"] = "RNA"
optimizer.param_groups[0]["lr"] = 1e-2

# %%
max_epochs = 300
early_stopping = EarlyStopping(15)

for epoch in range(max_epochs):
    train_loss = trainer.train_epoch(model, optimizer, dl["train"])
    optimizer.finish_epoch()
    val_acc, val_loss = trainer.validation(model, dl["valid"])
    logger.log("Epoch", epoch+1, "|", 
          f"Training loss: {train_loss:.4f}, validation accuracy: {val_acc:.4f}, validation loss: {val_loss:.4f}")
    if early_stopping.should_stop(val_loss):
        break
# Out:
# 100%|██████████| 313/313 [00:17<00:00, 18.07it/s, loss=0.2738]
# Epoch 1 | Training loss: 0.2738, validation accuracy: 0.8205, validation loss: 0.6276
# 100%|██████████| 313/313 [00:18<00:00, 17.18it/s, loss=0.2414]
# Epoch 2 | Training loss: 0.2414, validation accuracy: 0.8186, validation loss: 0.6539
# 100%|██████████| 313/313 [00:18<00:00, 17.21it/s, loss=0.2343]
# Epoch 3 | Training loss: 0.2343, validation accuracy: 0.8208, validation loss: 0.6523
# 100%|██████████| 313/313 [00:18<00:00, 17.19it/s, loss=0.2234]
# Epoch 4 | Training loss: 0.2234, validation accuracy: 0.8182, validation loss: 0.6645
# 100%|██████████| 313/313 [00:18<00:00, 17.34it/s, loss=0.2159]
# Epoch 5 | Training loss: 0.2159, validation accuracy: 0.8213, validation loss: 0.6676
# 100%|██████████| 313/313 [00:18<00:00, 17.31it/s, loss=0.2163]
# Epoch 6 | Training loss: 0.2163, validation accuracy: 0.8183, validation loss: 0.6783
# 100%|██████████| 313/313 [00:18<00:00, 17.29it/s, loss=0.2070]
# Epoch 7 | Training loss: 0.2070, validation accuracy: 0.8161, validation loss: 0.6906
# 100%|██████████| 313/313 [00:18<00:00, 17.33it/s, loss=0.2043]
# Epoch 8 | Training loss: 0.2043, validation accuracy: 0.8212, validation loss: 0.6582
# 100%|██████████| 313/313 [00:18<00:00, 17.23it/s, loss=0.2020]
# Epoch 9 | Training loss: 0.2020, validation accuracy: 0.8211, validation loss: 0.6779
# 100%|██████████| 313/313 [00:17<00:00, 17.39it/s, loss=0.2002]
# Epoch 10 | Training loss: 0.2002, validation accuracy: 0.8209, validation loss: 0.6740
# 100%|██████████| 313/313 [00:18<00:00, 17.26it/s, loss=0.1955]
# Epoch 11 | Training loss: 0.1955, validation accuracy: 0.8208, validation loss: 0.6794
# 100%|██████████| 313/313 [00:17<00:00, 17.45it/s, loss=0.1932]
# Epoch 12 | Training loss: 0.1932, validation accuracy: 0.8200, validation loss: 0.6744
# 100%|██████████| 313/313 [00:18<00:00, 17.38it/s, loss=0.1903]
# Epoch 13 | Training loss: 0.1903, validation accuracy: 0.8171, validation loss: 0.6983
# 100%|██████████| 313/313 [00:18<00:00, 17.27it/s, loss=0.1893]
# Epoch 14 | Training loss: 0.1893, validation accuracy: 0.8206, validation loss: 0.6854
# 100%|██████████| 313/313 [00:18<00:00, 17.26it/s, loss=0.1891]
# Epoch 15 | Training loss: 0.1891, validation accuracy: 0.8205, validation loss: 0.6864
# 100%|██████████| 313/313 [00:18<00:00, 17.23it/s, loss=0.1855]
# Epoch 16 | Training loss: 0.1855, validation accuracy: 0.8201, validation loss: 0.6990

# %%
train_score = trainer.validation(model, dl["train"])
valid_score = trainer.validation(model, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
# Out:
# Train: (0.944675, 0.15743565732240677)
# Valid: (0.8201, 0.6990071287155152)

# %%
optimizer.param_groups[0]["method"] = "RNA"
logger.log(optimizer.param_groups[0]["method"])
model.cpu()
model_acc = deepcopy(model)
optimizer.accelerate()
optimizer.store_parameters([model_acc.parameters()])
# Out:
# RNA

# %%
model_acc.cuda()
train_score = trainer.validation(model_acc, dl["train"])
valid_score = trainer.validation(model_acc, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
model_acc.cpu()
model.cuda()
# Out:
# Train: (0.94085, 0.16764365899562836)
# Valid: (0.8164, 0.7133902015686036)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )

# %%
optimizer.param_groups[0]["method"] = "RRE"
logger.log(optimizer.param_groups[0]["method"])
model.cpu()
model_acc = deepcopy(model)
optimizer.accelerate()
optimizer.store_parameters([model_acc.parameters()])
# Out:
# RRE

# %%
model_acc.cuda()
train_score = trainer.validation(model_acc, dl["train"])
valid_score = trainer.validation(model_acc, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
model_acc.cpu()
model.cuda()
# Out:
# Train: (0.93885, 0.17244319112300874)
# Valid: (0.8164, 0.7133904474258422)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )

# %%
optimizer.param_groups[0]["method"] = "RNA"
optimizer.param_groups[0]["lr"] = 1e-3

# %%
max_epochs = 300
early_stopping = EarlyStopping(15)

for epoch in range(max_epochs):
    train_loss = trainer.train_epoch(model, optimizer, dl["train"])
    optimizer.finish_epoch()
    val_acc, val_loss = trainer.validation(model, dl["valid"])
    logger.log("Epoch", epoch+1, "|", 
          f"Training loss: {train_loss:.4f}, validation accuracy: {val_acc:.4f}, validation loss: {val_loss:.4f}")
    if early_stopping.should_stop(val_loss):
        break
# Out:
# 100%|██████████| 313/313 [00:17<00:00, 17.82it/s, loss=0.1748]
# Epoch 1 | Training loss: 0.1748, validation accuracy: 0.8192, validation loss: 0.6881
# 100%|██████████| 313/313 [00:18<00:00, 17.28it/s, loss=0.1746]
# Epoch 2 | Training loss: 0.1746, validation accuracy: 0.8196, validation loss: 0.6862
# 100%|██████████| 313/313 [00:18<00:00, 17.19it/s, loss=0.1758]
# Epoch 3 | Training loss: 0.1758, validation accuracy: 0.8211, validation loss: 0.7002
# 100%|██████████| 313/313 [00:18<00:00, 17.22it/s, loss=0.1745]
# Epoch 4 | Training loss: 0.1745, validation accuracy: 0.8213, validation loss: 0.7023
# 100%|██████████| 313/313 [00:18<00:00, 17.25it/s, loss=0.1693]
# Epoch 5 | Training loss: 0.1693, validation accuracy: 0.8202, validation loss: 0.7023
# 100%|██████████| 313/313 [00:18<00:00, 17.31it/s, loss=0.1697]
# Epoch 6 | Training loss: 0.1697, validation accuracy: 0.8222, validation loss: 0.6859
# 100%|██████████| 313/313 [00:17<00:00, 17.42it/s, loss=0.1685]
# Epoch 7 | Training loss: 0.1685, validation accuracy: 0.8227, validation loss: 0.6944
# 100%|██████████| 313/313 [00:18<00:00, 17.12it/s, loss=0.1700]
# Epoch 8 | Training loss: 0.1700, validation accuracy: 0.8216, validation loss: 0.6959
# 100%|██████████| 313/313 [00:18<00:00, 17.34it/s, loss=0.1705]
# Epoch 9 | Training loss: 0.1705, validation accuracy: 0.8216, validation loss: 0.6948
# 100%|██████████| 313/313 [00:18<00:00, 17.22it/s, loss=0.1680]
# Epoch 10 | Training loss: 0.1680, validation accuracy: 0.8204, validation loss: 0.6954
# 100%|██████████| 313/313 [00:18<00:00, 17.26it/s, loss=0.1755]
# Epoch 11 | Training loss: 0.1755, validation accuracy: 0.8219, validation loss: 0.6913
# 100%|██████████| 313/313 [00:18<00:00, 17.36it/s, loss=0.1744]
# Epoch 12 | Training loss: 0.1744, validation accuracy: 0.8206, validation loss: 0.7008
# 100%|██████████| 313/313 [00:18<00:00, 17.26it/s, loss=0.1654]
# Epoch 13 | Training loss: 0.1654, validation accuracy: 0.8216, validation loss: 0.6970
# 100%|██████████| 313/313 [00:18<00:00, 17.25it/s, loss=0.1749]
# Epoch 14 | Training loss: 0.1749, validation accuracy: 0.8206, validation loss: 0.7016
# 100%|██████████| 313/313 [00:18<00:00, 17.20it/s, loss=0.1723]
# Epoch 15 | Training loss: 0.1723, validation accuracy: 0.8207, validation loss: 0.6976
# 100%|██████████| 313/313 [00:17<00:00, 17.47it/s, loss=0.1696]
# Epoch 16 | Training loss: 0.1696, validation accuracy: 0.8220, validation loss: 0.6980
# 100%|██████████| 313/313 [00:18<00:00, 17.20it/s, loss=0.1705]
# Epoch 17 | Training loss: 0.1705, validation accuracy: 0.8192, validation loss: 0.7050
# 100%|██████████| 313/313 [00:18<00:00, 17.35it/s, loss=0.1669]
# Epoch 18 | Training loss: 0.1669, validation accuracy: 0.8208, validation loss: 0.7050
# 100%|██████████| 313/313 [00:18<00:00, 17.38it/s, loss=0.1639]
# Epoch 19 | Training loss: 0.1639, validation accuracy: 0.8205, validation loss: 0.6994
# 100%|██████████| 313/313 [00:18<00:00, 17.14it/s, loss=0.1635]
# Epoch 20 | Training loss: 0.1635, validation accuracy: 0.8198, validation loss: 0.7051
# 100%|██████████| 313/313 [00:18<00:00, 17.17it/s, loss=0.1745]
# Epoch 21 | Training loss: 0.1745, validation accuracy: 0.8216, validation loss: 0.7109

# %%
train_score = trainer.validation(model, dl["train"])
valid_score = trainer.validation(model, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
# Out:
# Train: (0.9465, 0.15073162679672242)
# Valid: (0.8216, 0.7109279075622559)

# %%
optimizer.param_groups[0]["method"] = "RNA"
logger.log(optimizer.param_groups[0]["method"])
model.cpu()
model_acc = deepcopy(model)
optimizer.accelerate()
optimizer.store_parameters([model_acc.parameters()])
# Out:
# RNA

# %%
model_acc.cuda()
train_score = trainer.validation(model_acc, dl["train"])
valid_score = trainer.validation(model_acc, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
model_acc.cpu()
model.cuda()
# Out:
# Train: (0.947, 0.1494686625957489)
# Valid: (0.8199, 0.7110636493682861)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )

# %%
optimizer.param_groups[0]["method"] = "RRE"
logger.log(optimizer.param_groups[0]["method"])
model.cpu()
model_acc = deepcopy(model)
optimizer.accelerate()
optimizer.store_parameters([model_acc.parameters()])
# Out:
# RRE

# %%
model_acc.cuda()
train_score = trainer.validation(model_acc, dl["train"])
valid_score = trainer.validation(model_acc, dl["valid"])
logger.log("Train:", train_score)
logger.log("Valid:", valid_score)
model_acc.cpu()
model.cuda()
# Out:
# Train: (0.9479, 0.14747164417505265)
# Valid: (0.8199, 0.7110637641906739)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): LogSoftmax(dim=-1)
#   )
# )
